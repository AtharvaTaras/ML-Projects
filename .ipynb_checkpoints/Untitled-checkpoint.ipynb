# %% [markdown]
# # ML-Projects
# Machine Learning Projects in Python

# %% [markdown]
# # MAGIC Dataset
# Citation - https://archive.ics.uci.edu/dataset/159/magic+gamma+telescope
#
# The data are MC generated (see below) to simulate registration of high energy gamma particles in a ground-based atmospheric Cherenkov gamma telescope using the imaging technique. Cherenkov gamma telescope observes high energy gamma rays, taking advantage of the radiation emitted by charged particles produced inside the electromagnetic showers initiated by the gammas, and developing in the atmosphere. This Cherenkov radiation (of visible to UV wavelengths) leaks through the atmosphere and gets recorded in the detector, allowing reconstruction of the shower parameters. The available information consists of pulses left by the incoming Cherenkov photons on the photomultiplier tubes, arranged in a plane, the camera. Depending on the energy of the primary gamma, a total of few hundreds to some 10000 Cherenkov photons get collected, in patterns (called the shower image), allowing to discriminate statistically those caused by primary gammas (signal) from the images of hadronic showers initiated by cosmic rays in the upper atmosphere (background).
#
# Typically, the image of a shower after some pre-processing is an elongated cluster. Its long axis is oriented towards the camera center if the shower axis is parallel to the telescope's optical axis, i.e. if the telescope axis is directed towards a point source. A principal component analysis is performed in the camera plane, which results in a correlation axis and defines an ellipse. If the depositions were distributed as a bivariate Gaussian, this would be an equidensity ellipse. The characteristic parameters of this ellipse (often called Hillas parameters) are among the image parameters that can be used for discrimination. The energy depositions are typically asymmetric along the major axis, and this asymmetry can also be used in discrimination. There are, in addition, further discriminating characteristics, like the extent of the cluster in the image plane, or the total sum of depositions.
#
# The data set was generated by a Monte Carlo program, Corsika, described in:
# D. Heck et al., CORSIKA, A Monte Carlo code to simulate extensive air showers, Forschungszentrum Karlsruhe FZKA 6019 (1998).
# http://rexa.info/paper?id=ac6e674e9af20979b23d3ed4521f1570765e8d68
#
# The program was run with parameters allowing to observe events with energies down to below 50 GeV.
#
# Additional Information
#
#     1.  fLength:  continuous  # major axis of ellipse [mm]
#     2.  fWidth:   continuous  # minor axis of ellipse [mm]
#     3.  fSize:    continuous  # 10-log of sum of content of all pixels [in #phot]
#     4.  fConc:    continuous  # ratio of sum of two highest pixels over fSize  [ratio]
#     5.  fConc1:   continuous  # ratio of highest pixel over fSize  [ratio]
#     6.  fAsym:    continuous  # distance from highest pixel to center, projected onto major axis [mm]
#     7.  fM3Long:  continuous  # 3rd root of third moment along major axis  [mm]
#     8.  fM3Trans: continuous  # 3rd root of third moment along minor axis  [mm]
#     9.  fAlpha:   continuous  # angle of major axis with vector to origin [deg]
#     10. fDist:    continuous  # distance from origin to center of ellipse [mm]
#     11. class:    g,h         # gamma (signal), hadron (background)
#
#    g = gamma (signal):     12332
#    h = hadron (background): 6688
#
# For technical reasons, the number of h events is underestimated. In the real data, the h class represents the majority of the events.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from imblearn.over_sampling import RandomOverSampler
from sklearn.svm import SVC

# %%
data = pd.read_csv('datasets/magic04.data', 
                   names=['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 'fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist', 'class'])

# %%
data.head()
# Out:
#     fLength    fWidth   fSize   fConc  fConc1     fAsym  fM3Long  fM3Trans  \
# 0   28.7967   16.0021  2.6449  0.3918  0.1982   27.7004  22.0110   -8.2027
# 1   31.6036   11.7235  2.5185  0.5303  0.3773   26.2722  23.8238   -9.9574
# 2  162.0520  136.0310  4.0612  0.0374  0.0187  116.7410 -64.8580  -45.2160
# 3   23.8172    9.5728  2.3385  0.6147  0.3922   27.2107  -6.4633   -7.1513
# 4   75.1362   30.9205  3.1611  0.3168  0.1832   -5.5277  28.5525   21.8393
#
#     fAlpha     fDist class
# 0  40.0920   81.8828     g
# 1   6.3609  205.2610     g
# 2  76.9600  256.7880     g
# 3  10.4490  116.7370     g
# 4   4.6480  356.4620     g

# %%
data['class'].unique()
# Out:
# array(['g', 'h'], dtype=object)

# %%
data['class'] = (data['class'] == 'g').astype(int)

# %% [markdown]
# ##### Categorical to numerical variable conversion

# %%
data['class'].unique()
# Out:
# array([1, 0])

# %%
data.isnull().sum()
# Out:
# fLength     0
# fWidth      0
# fSize       0
# fConc       0
# fConc1      0
# fAsym       0
# fM3Long     0
# fM3Trans    0
# fAlpha      0
# fDist       0
# class       0
# dtype: int64

# %%
data.describe()
# Out:
#             fLength        fWidth         fSize         fConc        fConc1  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      53.250154     22.180966      2.825017      0.380327      0.214657
# std       42.364855     18.346056      0.472599      0.182813      0.110511
# min        4.283500      0.000000      1.941300      0.013100      0.000300
# 25%       24.336000     11.863800      2.477100      0.235800      0.128475
# 50%       37.147700     17.139900      2.739600      0.354150      0.196500
# 75%       70.122175     24.739475      3.101600      0.503700      0.285225
# max      334.177000    256.382000      5.323300      0.893000      0.675200
#
#               fAsym       fM3Long      fM3Trans        fAlpha         fDist  \
# count  19020.000000  19020.000000  19020.000000  19020.000000  19020.000000
# mean      -4.331745     10.545545      0.249726     27.645707    193.818026
# ...

# %% [markdown]
# ##### Class wise histogram plot

# %%
for label in ['fLength', 'fWidth', 'fSize', 'fConc', 'fConc1', 'fAsym', 'fM3Long', 'fM3Trans', 'fAlpha', 'fDist']:
    plt.hist(data[data['class']==1][label], color='blue', label='Gamma (g class)', alpha=0.5, density=True)
    plt.hist(data[data['class']==0][label], color='red', label='Hadron (h class)', alpha=0.5, density=True)
    plt.title(label.upper())
    plt.legend()
    plt.show()

# %% [markdown]
# ##### Splitting data using numpy

# %%
train, valid, test = np.split(data.sample(frac=1), [int(0.6*len(data)), int(0.8*len(data))])

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11412 entries, 867 to 12170
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fLength   11412 non-null  float64
#  1   fWidth    11412 non-null  float64
#  2   fSize     11412 non-null  float64
#  3   fConc     11412 non-null  float64
#  4   fConc1    11412 non-null  float64
#  5   fAsym     11412 non-null  float64
#  6   fM3Long   11412 non-null  float64
#  7   fM3Trans  11412 non-null  float64
#  8   fAlpha    11412 non-null  float64
#  9   fDist     11412 non-null  float64
#  10  class     11412 non-null  int32
# dtypes: float64(10), int32(1)
# memory usage: 1.0 MB

# %%
valid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3804 entries, 5495 to 12131
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fLength   3804 non-null   float64
#  1   fWidth    3804 non-null   float64
#  2   fSize     3804 non-null   float64
#  3   fConc     3804 non-null   float64
#  4   fConc1    3804 non-null   float64
#  5   fAsym     3804 non-null   float64
#  6   fM3Long   3804 non-null   float64
#  7   fM3Trans  3804 non-null   float64
#  8   fAlpha    3804 non-null   float64
#  9   fDist     3804 non-null   float64
#  10  class     3804 non-null   int32
# dtypes: float64(10), int32(1)
# memory usage: 341.8 KB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3804 entries, 4777 to 1037
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   fLength   3804 non-null   float64
#  1   fWidth    3804 non-null   float64
#  2   fSize     3804 non-null   float64
#  3   fConc     3804 non-null   float64
#  4   fConc1    3804 non-null   float64
#  5   fAsym     3804 non-null   float64
#  6   fM3Long   3804 non-null   float64
#  7   fM3Trans  3804 non-null   float64
#  8   fAlpha    3804 non-null   float64
#  9   fDist     3804 non-null   float64
#  10  class     3804 non-null   int32
# dtypes: float64(10), int32(1)
# memory usage: 341.8 KB

# %% [markdown]
# ##### Noramalization/scaling function

# %%
def scale_dataset(df, oversample=False):
    X = df[df.columns[:-1]].values
    y = df[df.columns[-1]].values
    
    scaler = StandardScaler()
    X = scaler.fit_transform(X)
    
    if oversample:
        ros = RandomOverSampler()
        X, y = ros.fit_resample(X, y)
    
    # Horizintally stack data
    data = np.hstack((X, np.reshape(y, (-1, 1))))
    
    return data, X, y

# %% [markdown]
# ##### Checking imbalance in dataset classes

# %%
print('g', len(train[train['class']==1]))
print('h', len(train[train['class']==0]))
# Out:
# g 7344
# h 4068

# %%
train, X_train, y_train = scale_dataset(train, oversample=True)

# fixing imbalance and scaling

# %%
print(sum(y_train == 1))
print(sum(y_train == 0))
# Out:
# 7344
# 7344

# %% [markdown]
# ##### Creating scaled datasets

# %%
valid, X_valid, y_valid = scale_dataset(valid, oversample=False)
test, X_test, y_test = scale_dataset(test, oversample=False)

# %% [markdown]
# ### KNN

# %%
knn_model = KNeighborsClassifier(n_neighbors=1)
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
y_pred = knn_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.69      0.72      1337
#            1       0.84      0.89      0.86      2467
#
#     accuracy                           0.82      3804
#    macro avg       0.80      0.79      0.79      3804
# weighted avg       0.81      0.82      0.81      3804

# %%
knn_model = KNeighborsClassifier(n_neighbors=3)
knn_model.fit(X_train, y_train)

y_pred = knn_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.74      0.73      1337
#            1       0.86      0.85      0.85      2467
#
#     accuracy                           0.81      3804
#    macro avg       0.79      0.79      0.79      3804
# weighted avg       0.81      0.81      0.81      3804

# %%
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_model.fit(X_train, y_train)

y_pred = knn_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.74      0.74      1337
#            1       0.86      0.86      0.86      2467
#
#     accuracy                           0.82      3804
#    macro avg       0.80      0.80      0.80      3804
# weighted avg       0.82      0.82      0.82      3804

# %% [markdown]
# ### Naive Bayes

# %%
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = nb_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.42      0.52      1337
#            1       0.74      0.89      0.81      2467
#
#     accuracy                           0.73      3804
#    macro avg       0.71      0.66      0.66      3804
# weighted avg       0.72      0.73      0.71      3804

# %% [markdown]
# ### Logisitic Regression

# %%
lg_model = LogisticRegression()
lg_model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lg_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.71      1337
#            1       0.85      0.83      0.84      2467
#
#     accuracy                           0.79      3804
#    macro avg       0.77      0.78      0.78      3804
# weighted avg       0.80      0.79      0.79      3804

# %%
svc_model = SVC()
svc_model.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = svc_model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.80      1337
#            1       0.89      0.89      0.89      2467
#
#     accuracy                           0.86      3804
#    macro avg       0.84      0.84      0.84      3804
# weighted avg       0.86      0.86      0.86      3804

# %%
import tensorflow as tf

# %%
def plot_loss(history):
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.xlabel('Epoch')
    plt.ylabel('Binary Crossentropy')
    plt.legend()
    plt.grid(True)
    plt.show()
    
def plot_accuracy(history):
    plt.plot(history.history['accuracy'], label='accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
nn_model = tf.keras.Sequential([
    tf.keras.layers.Dense(32, activation='relu', input_shape=(10,)),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid'),
])

nn_model.compile(optimizer=tf.keras.optimizers.Adam(0.001),
                 loss='binary_crossentropy',
                 metrics=['accuracy'])

# %%
history = nn_model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=0)

# %%
plot_loss(history)
plot_accuracy(history)

# %%
def train_model(X_traindata, y_traindata, num_nodes, dropout_probab, learn_rate, batch_size, epochs, vd):
    
    nn_model = tf.keras.Sequential([
    tf.keras.layers.Dense(num_nodes, activation='relu', input_shape=(10,)),
    tf.keras.layers.Dropout(dropout_probab),
    tf.keras.layers.Dense(num_nodes, activation='relu'),
    tf.keras.layers.Dropout(dropout_probab),
    tf.keras.layers.Dense(1, activation='sigmoid'),
    ])

    nn_model.compile(optimizer=tf.keras.optimizers.Adam(learn_rate),
                           loss='binary_crossentropy',
                           metrics=['accuracy'])
    
    history = nn_model.fit(X_traindata, y_traindata, epochs=epochs, batch_size=batch_size, verbose=0, validation_data=vd)

    return nn_model, history

# %%
def plot_loss_acc(history):
    
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    
    ax1.plot(history.history['loss'], label='loss')
    ax1.plot(history.history['val_loss'], label='val_loss')
    ax1.set_xlabel('Epoch')
    ax1.set_ylabel('Binary Crossentropy')
    ax1.legend()
    
    ax2.plot(history.history['accuracy'], label='accuracy')
    ax2.plot(history.history['val_accuracy'], label='val_accuracy')
    ax2.set_xlabel('Epoch')
    ax2.set_ylabel('Accuracy')
    ax2.legend()
    
    plt.show()

# %%
least_val_loss = 99999999
least_loss_model = None

for nodes in [16, 32, 64]:
    for probab in [0, 0.2]:
        for lr in [0.01, 0.005, 0.001]:
            for batch in [32, 64, 128]:

                print(f'Nodes {nodes} Dropout {probab} Learning {lr} BatchSize {batch}')

                model, history = train_model(X_train, 
                                             y_train, 
                                             num_nodes=nodes,
                                             dropout_probab=probab,
                                             learn_rate=lr,
                                             batch_size=batch,
                                             epochs=100,
                                             vd=(X_valid, y_valid))

                val_loss, val_accuracy = model.evaluate(X_valid, y_valid)

                if val_loss < least_val_loss:
                    least_val_loss = val_loss
                    least_loss_model = model
                    
                plot_loss_acc(history)
# Out:
# Nodes 16 Dropout 0 Learning 0.01 BatchSize 32
# Nodes 16 Dropout 0 Learning 0.01 BatchSize 64
# Nodes 16 Dropout 0 Learning 0.01 BatchSize 128
# Nodes 16 Dropout 0 Learning 0.005 BatchSize 32
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[66], line 11
#       7 for batch in [32, 64, 128]:
#       9     print(f'Nodes {nodes} Dropout {probab} Learning {lr} BatchSize {batch}')
# ---> 11     model, history = train_model(X_train,
#      12                                  y_train,
#      13                                  num_nodes=nodes,
#      14                                  dropout_probab=probab,
#      15                                  learn_rate=lr,
#      16                                  batch_size=batch,
#      17                                  epochs=10,
#      18                                  vd=(X_valid, y_valid))
# ...
